# %%
# !pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 133kB 8.3MB/s
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !git clone https://github.com/cjhutto/vaderSentiment.git
# Out:
# Cloning into 'vaderSentiment'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 381 (delta 34), reused 7 (delta 1), pack-reused 325
# Receiving objects: 100% (381/381), 2.67 MiB | 4.44 MiB/s, done.
# Resolving deltas: 100% (222/222), done.

# %%
cd /content/drive/My Drive/VADER/vaderSentiment/vaderSentiment
# Out:
# /content/drive/My Drive/VADER/vaderSentiment/vaderSentiment

# %%
cd ..
# Out:
# /content/drive/My Drive/VADER

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import glob
analyzer = SentimentIntensityAnalyzer();
# function to print sentiments 
# of the sentence. 
dataset=input('Wich Dataset(1,2 or 3): ')
path='./'+dataset+'/*.txt' 
files = glob.glob(path)
dic={}
for n in files:
	x=n.split('/')
	id=x[len(x)-1].split('.')
	dic[int(id[0])]= n
sorted_dict = {k: dic[k] for k in sorted(dic)}
print(len(sorted_dict))
ava_accuracy=0;
for k,n in sorted_dict.items():
    p=n.replace('\\','/')
    # load data
    win=pd.read_csv(p,delimiter='\t', header=0, encoding = "latin-1",index_col=0)

    count=0
    true=0
    test=0
    for label, review in win.iterrows():
      test+=1;
     # print(str(count), '    '+review[0]) #tesssssssssssssssssssssssssssst
      if sentiment_analyzer_scores(review[0])== label:
        true=true+1 
      count=count+1

    accuracy= (true/count)*100;
    print(str(k), ' The accuracy is '+ str(accuracy))
    ava_accuracy=ava_accuracy+accuracy
print('The avarege accuracy is ', ava_accuracy/len(sorted_dict))
def clean_ascii(text):
    return ''.join(i for i in text if ord(i) < 128)

def sentiment_analyzer_scores(text):
    score = analyzer.polarity_scores(clean_ascii(text))
    lb = score['compound']
    if lb >= 0:
        return 'POS'
    else:
        return 'NEG'
# Out:
# Wich Dataset(1,2 or 3): 4
# 21
# 1  The accuracy is 66.12903225806451
# 2  The accuracy is 66.66666666666666
# 3  The accuracy is 71.42857142857143
# 4  The accuracy is 61.53846153846154
# 5  The accuracy is 86.66666666666667
# 6  The accuracy is 94.5945945945946
# 7  The accuracy is 81.25
# 8  The accuracy is 78.26086956521739
# 9  The accuracy is 75.0
# 10  The accuracy is 95.1219512195122
# 11  The accuracy is 87.5
# 12  The accuracy is 100.0
# 13  The accuracy is 96.7741935483871
# 14  The accuracy is 91.37931034482759
# 15  The accuracy is 91.1504424778761
# 16  The accuracy is 96.42857142857143
# 17  The accuracy is 90.82568807339449
# 18  The accuracy is 84.52380952380952
# 19  The accuracy is 61.76470588235294
# 20  The accuracy is 78.125
# 21  The accuracy is 73.07692307692307
# The avarege accuracy is  82.2954980139951

# %% [markdown]
# Wich Dataset(1,2 or 3): 4
# 21
# 1  The accuracy is 66.12903225806451
# 2  The accuracy is 66.66666666666666
# 3  The accuracy is 71.42857142857143
# 4  The accuracy is 61.53846153846154
# 5  The accuracy is 86.66666666666667
# 6  The accuracy is 94.5945945945946
# 7  The accuracy is 81.25
# 8  The accuracy is 78.26086956521739
# 9  The accuracy is 75.0
# 10  The accuracy is 95.1219512195122
# 11  The accuracy is 87.5
# 12  The accuracy is 100.0
# 13  The accuracy is 96.7741935483871
# 14  The accuracy is 91.37931034482759
# 15  The accuracy is 91.1504424778761
# 16  The accuracy is 96.42857142857143
# 17  The accuracy is 90.82568807339449
# 18  The accuracy is 84.52380952380952
# 19  The accuracy is 61.76470588235294
# 20  The accuracy is 78.125
# 21  The accuracy is 73.07692307692307
# The avarege accuracy is  82.2954980139951

# %% [markdown]
# Wich Dataset(1,2 or 3): 3
# 16
# 1  The accuracy is 85.41666666666666
# 2  The accuracy is 82.08955223880598
# 3  The accuracy is 80.53097345132744
# 4  The accuracy is 80.6930693069307
# 5  The accuracy is 77.47747747747748
# 6  The accuracy is 75.92592592592592
# 7  The accuracy is 73.95833333333334
# 8  The accuracy is 86.11111111111111
# 9  The accuracy is 79.00552486187846
# 10  The accuracy is 82.55451713395638
# 11  The accuracy is 80.21978021978022
# 12  The accuracy is 84.4106463878327
# 13  The accuracy is 86.27450980392157
# 14  The accuracy is 85.2760736196319
# 15  The accuracy is 83.06636155606407
# 16  The accuracy is 74.94866529774127
# The avarege accuracy is  81.12244927452406

# %% [markdown]
# Wich Dataset(1,2 or 3): 2
# 16
# 1  The accuracy is 82.5
# 2  The accuracy is 89.58333333333334
# 3  The accuracy is 77.77777777777779
# 4  The accuracy is 84.89583333333334
# 5  The accuracy is 85.5072463768116
# 6  The accuracy is 81.53846153846153
# 7  The accuracy is 83.33333333333334
# 8  The accuracy is 73.68421052631578
# 9  The accuracy is 83.06010928961749
# 10  The accuracy is 85.0909090909091
# 11  The accuracy is 77.41935483870968
# 12  The accuracy is 86.77248677248677
# 13  The accuracy is 85.84905660377359
# 14  The accuracy is 84.14096916299559
# 15  The accuracy is 79.0909090909091
# 16  The accuracy is 81.46853146853147
# The avarege accuracy is  82.60703265858122

# %% [markdown]
# Wich Dataset(1,2 or 3): 1
# 16
# 1  The accuracy is 75.0
# 2  The accuracy is 81.3953488372093
# 3  The accuracy is 77.77777777777779
# 4  The accuracy is 75.77092511013215
# 5  The accuracy is 77.87610619469027
# 6  The accuracy is 80.3030303030303
# 7  The accuracy is 69.23076923076923
# 8  The accuracy is 75.72815533980582
# 9  The accuracy is 79.8941798941799
# 10  The accuracy is 75.0
# 11  The accuracy is 77.10843373493977
# 12  The accuracy is 76.10921501706484
# 13  The accuracy is 75.1937984496124
# 14  The accuracy is 81.64556962025317
# 15  The accuracy is 77.43589743589745
# 16  The accuracy is 79.34560327198365
# The avarege accuracy is  *77.17592563858412*
